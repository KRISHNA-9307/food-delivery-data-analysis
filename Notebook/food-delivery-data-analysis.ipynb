# %%
import pandas as pd
import sqlite3

# %%
#Loading orders.csv file

# %%
orders_df = pd.read_csv("C:/Users/gopi9/OneDrive/Desktop/IRIS/DATA/orders.csv")
orders_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name
# 0               New Foods Chinese
# 1  Ruchi Curry House Multicuisine
# 2           Spice Kitchen Punjabi
# 3          Darbar Kitchen Non-Veg
# 4       Royal Eatery South Indian

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_id         10000 non-null  int64
#  1   user_id          10000 non-null  int64
#  2   restaurant_id    10000 non-null  int64
#  3   order_date       10000 non-null  object
#  4   total_amount     10000 non-null  float64
#  5   restaurant_name  10000 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 468.9+ KB

# %%
#Loading users.json file

# %%
users_df = pd.read_json("C:/Users/gopi9/OneDrive/Desktop/IRIS/DATA/users.json")
users_df.head()
# Out:
#    user_id    name       city membership
# 0        1  User_1    Chennai    Regular
# 1        2  User_2       Pune       Gold
# 2        3  User_3  Bangalore       Gold
# 3        4  User_4  Bangalore    Regular
# 4        5  User_5       Pune       Gold

# %%
#Loading restaurant.db file

# %%
conn = sqlite3.connect("C:/Users/gopi9/OneDrive/Desktop/IRIS/DATA/restaurants.db")

restaurants_df = pd.read_sql(
    "SELECT * FROM restaurants",
    conn
)

restaurants_df.head()
# Out:
#    restaurant_id restaurant_name  cuisine  rating
# 0              1    Restaurant_1  Chinese     4.8
# 1              2    Restaurant_2   Indian     4.1
# 2              3    Restaurant_3  Mexican     4.3
# 3              4    Restaurant_4  Chinese     4.1
# 4              5    Restaurant_5  Chinese     4.8

# %%
orders_df.columns
# Out:
# Index(['order_id', 'user_id', 'restaurant_id', 'order_date', 'total_amount',
#        'restaurant_name'],
#       dtype='object')

# %%
users_df.columns
# Out:
# Index(['user_id', 'name', 'city', 'membership'], dtype='object')

# %%
restaurants_df.columns
# Out:
# Index(['restaurant_id', 'restaurant_name', 'cuisine', 'rating'], dtype='object')

# %%
#Merging the files

# %%
orders_users_df = pd.merge(
    orders_df,
    users_df,
    on="user_id",
    how="left"
)

orders_users_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                   restaurant_name       name       city membership
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular

# %%
final_df = pd.merge(
    orders_users_df,
    restaurants_df,
    on="restaurant_id",
    how="left"
)
final_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# ...

# %%
final_df.to_csv("C:/Users/gopi9/OneDrive/Desktop/IRIS/DATA/final_food_delivery_dataset.csv", index=False)

# %%
final_df = pd.read_csv("final_food_delivery_dataset.csv")
final_df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# ...

# %%
final_df.head()
# Out:
#    order_id  user_id  restaurant_id order_date  total_amount  \
# 0         1     2508            450 2023-02-18        842.97
# 1         2     2693            309 2023-01-18        546.68
# 2         3     2084            107 2023-07-15        163.93
# 3         4      319            224 2023-10-04       1155.97
# 4         5     1064            293 2023-12-25       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating  quarter
# 0    Restaurant_450  Mexican     3.2        1
# 1    Restaurant_309   Indian     4.5        1
# 2    Restaurant_107  Mexican     4.0        3
# ...

# %%
final_df.shape
# Out:
# (10000, 12)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           10000 non-null  int64
#  1   user_id            10000 non-null  int64
#  2   restaurant_id      10000 non-null  int64
#  3   order_date         10000 non-null  object
#  4   total_amount       10000 non-null  float64
#  5   restaurant_name_x  10000 non-null  object
#  6   name               10000 non-null  object
#  7   city               10000 non-null  object
#  8   membership         10000 non-null  object
#  9   restaurant_name_y  10000 non-null  object
#  10  cuisine            10000 non-null  object
#  11  rating             10000 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 937.6+ KB

# %%
final_df["order_id"].nunique()
# Out:
# 10000

# %%
final_df["total_amount"].sum()
# Out:
# np.float64(8011624.12)

# %%
# The total revenue is ₹80,11,624.12  across 10,000 orders.

# %%
final_df.groupby("membership")["total_amount"].sum()
# Out:
# membership
# Gold       3975364.89
# Regular    4036259.23
# Name: total_amount, dtype: float64

# %%
#Observations
#Regular users contribute slightly more total revenue than Gold users

# %%
final_df.groupby("membership")["order_id"].count()
# Out:
# membership
# Gold       4987
# Regular    5013
# Name: order_id, dtype: int64

# %%
#Both Gold and Regular users has almost same order count with regular users having slightly more count

# %%
final_df.groupby("membership")["total_amount"].mean()
# Out:
# membership
# Gold       797.145556
# Regular    805.158434
# Name: total_amount, dtype: float64

# %%
#The analysis shows that Regular users outperform Gold users across all metrics—order count, total revenue, and average order value.

# %%
final_df.groupby("city")["order_id"].count().sort_values(ascending=False)
# Out:
# city
# Bangalore    2751
# Chennai      2469
# Pune         2430
# Hyderabad    2350
# Name: order_id, dtype: int64

# %%
#Observations
#Bangalore has the highest order volume.
#Orders are evenly distributed across all cities.
#No single city dominates completely.

# %%
final_df.groupby("city")["total_amount"].sum().sort_values(ascending=False)
# Out:
# city
# Bangalore    2206946.58
# Chennai      1990513.03
# Pune         1924797.93
# Hyderabad    1889366.58
# Name: total_amount, dtype: float64

# %%
#Key points
#Bangalore leads both in volume and revenue.
#Demand is balanced across cities.

# %%
final_df.groupby("city")["total_amount"].mean().sort_values(ascending=False)
# Out:
# city
# Chennai      806.202118
# Hyderabad    803.985779
# Bangalore    802.234308
# Pune         792.097914
# Name: total_amount, dtype: float64

# %%
#FINAL CITY INSIGHTS
#Bangalore
#Highest orders & revenue
#Chennai
#Highest Average value
#Fewer orders than Bangalore, but higher spending per order
#Hyderabad
#Balanced performance
#Pune
#Lowest Average value

# %%
final_df.groupby("cuisine")["order_id"].count().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    2581
# Italian    2532
# Indian     2469
# Chinese    2418
# Name: order_id, dtype: int64

# %%
#Key Observations
#Mexican cuisine is the most ordered
#Italian and Indian cuisines follow closely
#No cuisine dominates

# %%
final_df.groupby("cuisine")["total_amount"].sum().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    2085503.09
# Italian    2024203.80
# Indian     1971412.58
# Chinese    1930504.65
# Name: total_amount, dtype: float64

# %%
#Key Observations
#Mexican cuisine hs both order volume and revenue
#Italian and Indian cuisines has consistent performance
#Chinese cuisines has lowest performance

# %%
final_df.groupby("cuisine")["total_amount"].mean().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
#multiple questions solved

# %%
final_df[final_df["membership"]=="Gold"] \
    .groupby("city")["total_amount"].sum().sort_values(ascending=False)
# Out:
# city
# Chennai      1080909.79
# Pune         1003012.32
# Bangalore     994702.59
# Hyderabad     896740.19
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine")["total_amount"].mean().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
user_total = final_df.groupby("user_id")["total_amount"].sum()
count_users = user_total[user_total > 1000].count()
count_users
# Out:
# np.int64(2544)

# %%
bins = [3.0, 3.5, 4.0, 4.5, 5.0]
labels = ["3.0–3.5", "3.6–4.0", "4.1–4.5", "4.6–5.0"]

final_df["rating_range"] = pd.cut(
    final_df["rating"], bins=bins, labels=labels
)

final_df.groupby("rating_range", observed=False)["total_amount"].sum()
# Out:
# rating_range
# 3.0–3.5    1881754.57
# 3.6–4.0    1717494.41
# 4.1–4.5    1960326.26
# 4.6–5.0    2197030.75
# Name: total_amount, dtype: float64

# %%
final_df[final_df["membership"] == "Gold"] \
    .groupby("city")["total_amount"].mean() \
    .sort_values(ascending=False)
# Out:
# city
# Chennai      808.459080
# Hyderabad    806.421034
# Bangalore    793.223756
# Pune         781.162243
# Name: total_amount, dtype: float64

# %%
final_df.groupby("cuisine")["restaurant_id"].nunique().sort_values()
# Out:
# cuisine
# Chinese    120
# Indian     126
# Italian    126
# Mexican    128
# Name: restaurant_id, dtype: int64

# %%
final_df.groupby("cuisine")["total_amount"].sum().sort_values(ascending=False)
# Out:
# cuisine
# Mexican    2085503.09
# Italian    2024203.80
# Indian     1971412.58
# Chinese    1930504.65
# Name: total_amount, dtype: float64

# %%
final_df.groupby("restaurant_name_y") \
    .agg(
        total_orders=("order_id", "count"),
        avg_order_value=("total_amount", "mean")
    ) \
    .query("total_orders < 20") \
    .sort_values("avg_order_value", ascending=False) \
    .head()
# Out:
#                    total_orders  avg_order_value
# restaurant_name_y
# Restaurant_294               13      1040.222308
# Restaurant_262               18      1029.473333
# Restaurant_77                12      1029.180833
# Restaurant_193               15      1026.306667
# Restaurant_7                 16      1002.140625

# %%
final_df.groupby(
    ["membership", "cuisine"]
)["total_amount"].sum().sort_values(ascending=False)
# Out:
# membership  cuisine
# Regular     Mexican    1072943.30
#             Italian    1018424.75
# Gold        Mexican    1012559.79
#             Italian    1005779.05
# Regular     Indian      992100.27
# Gold        Indian      979312.31
#             Chinese     977713.74
# Regular     Chinese     952790.91
# Name: total_amount, dtype: float64

# %%
final_df["user_id"].nunique()
# Out:
# 2883

# %%
round(
    final_df[final_df["membership"] == "Gold"]["total_amount"].mean(),
    2
)
# Out:
# np.float64(797.15)

# %%
final_df[final_df["rating"] >= 4.5]["order_id"].count()
# Out:
# np.int64(3374)

# %%
gold_top_city = (
    final_df[final_df["membership"] == "Gold"]
    .groupby("city")["total_amount"]
    .sum()
    .idxmax()
)

gold_top_city
# Out:
# 'Chennai'

# %%
final_df[
    (final_df["membership"] == "Gold") &
    (final_df["city"] == gold_top_city)
]["order_id"].count()
# Out:
# np.int64(1337)
